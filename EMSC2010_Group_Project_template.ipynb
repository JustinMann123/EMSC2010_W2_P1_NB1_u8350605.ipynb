# %% [markdown]
# <a href="https://colab.research.google.com/github/JustinMann123/EMSC2010_W2_P1_NB1_u8350605.ipynb/blob/main/EMSC2010_Group_Project_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010 Group Project -- A2: Weekly Project 4 -- 	Correlation and regression

# %% [markdown]
# ## 1. Project Overview
# Group name: Seismic Babes
#
# Project week:4
#
# Project title: TBD
#
# Datasets used (name and source):TBD

# %% [markdown]
# ## 2. Roles and contributions
#
# | Role | Primary | Deputy | Completed? | Notes |
# | :--- | :--- | :--- | :--- | :--- |
# | Github & integration | Justin Mann | Edward Obrien| Yes/Partial/No| Add note|
# | Data steward | Edward Obrien | Clover Barnard | Yes/Partial/No| Add note|
# | Analysis / modelling | Clover Barnard | Justin mann | Yes/Partial/No| Add note|
# | Visualisation / interpretation | Frederique Lawrence | Eloise Day | Yes/Partial/No| Add note|
# | Narrative | Owen Douglas | Frederique Lawrence | Yes/Partial/No| Add note|
# | Quality Control / Reproducibility  | Eloise Day | Owen Douglas | Yes/Partial/No/NA| Add note|

# %% [markdown]
# ## 3. Deputy Interventions (if applicable)
# Repeat text as required.
#
# * Role affected:
#
# * Reason (e.g. missed deadline, absence, etc.):
#
# * Deputy action taken:
#
# * Impact on workflow:
#
# *N.B., this section should be factual, not judgemental.*

# %% [markdown]
# ## 4. Pre-submission checklist
# * Notebook runs from top to bottom.
# * Datafiles are included in the GitHub repository.
# * Commits include meaningful information.
# * Each group member has included a brief reflection in the notebook.
# * Repository has been shared with the teaching team once your project is completed.

# %% [markdown]
# # Start your group project here

# %% [markdown]
# ## Question

# %% [markdown]
# # Hypothesis and Justification

# %% [markdown]
# # Data Import - Edward

# %% [markdown]
# # Analysis / Modelling - Clover & Freddie

# %% [markdown]
# # Visualisation - Clover & Freddie

# %% [markdown]
# # Interpretation - owen

# %% [markdown]
# # Individual Reflections

# %% [markdown]
# ### Data Steward - Ed

# %% [markdown]
# ### Analysis and Modelling / Visualisation and Interpretation - Freddie

# %% [markdown]
# ### Analysis and Modelling / Visualisation and Interpretation - Clover

# %% [markdown]
# ### Narrative - Owen

# %% [markdown]
# ### Github and Integration - Jusitn

# %% [markdown]
# ### Quality Control and Reproducibility - Ellie
