# %% [markdown]
# <a href="https://colab.research.google.com/github/JustinMann123/EMSC2010_W2_P1_NB1_u8350605.ipynb/blob/main/Copy_of_EMSC2010_W9_L1_NB1_u8350605.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010-W9-L1-NB1
# Model Earth's surface temperature (in Kelvin) using a zero-dimensional energy balance model without an atmosphere.
#
# $T_e = \left[ \frac{S}{4 \alpha} (1-A)\right]^{1/4}$
#
# where:
# * $T_e$ is Earth's surface temperature in Kelvin
# * $S$ is the solar flux (1366 W/m$^2$)
# * $A$ is albedo (currently around 0.3)
# * $\alpha$ is the Stefan-Boltmann constant (5.67E-8 W/m$^2$/K$^4$)

# %%
###

S= 1366
A= 0.
sigma = 5.67e-8

Te= (S/(4*sigma)*(1-A))**0.25
print(Te)
# Out:
# 278.5812689476053
